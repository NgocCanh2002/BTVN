# %% [markdown]
# <a href="https://colab.research.google.com/github/NgocCanh2002/Colab-cua-Ngoc-Canh/blob/main/27_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 26.0 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=d9dc7f8b6ab9cc5ef1005b8fa003142d38fde8b1e004792fe531d17e5624abcb
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
wind = ctrl.Antecedent(np.arange(0.7,3.1,0.1),"wind")
rainfall = ctrl.Antecedent(np.arange(0.2,9.2,0.1),"rainfall")
temparature = ctrl.Consequent(np.arange(20.4,41.2,0.1),"temparation")

wind['very low'] = fuzz.trimf(wind.universe,[0,0.2,0.25])
wind['low'] = fuzz.trimf(wind.universe,[0,0.25,0.5])
wind['normal'] = fuzz.trimf(wind.universe,[0.25,0.5,0.75])
wind['high'] = fuzz.trimf(wind.universe,[0.5,0.75,1])
wind['very high'] = fuzz.trimf(wind.universe,[0.75,0.85,1])

rainfall['very low'] = fuzz.trimf(rainfall.universe,[0,0.2,0.25])
rainfall['low'] = fuzz.trimf(rainfall.universe,[0,0.25,0.5])
rainfall['normal'] = fuzz.trimf(rainfall.universe,[0.25,0.5,0.75])
rainfall['high'] = fuzz.trimf(rainfall.universe,[0.5,0.75,1])
rainfall['very high'] = fuzz.trimf(rainfall.universe,[0.75,0.85,1])

temparature['very low'] = fuzz.trimf(temparature.universe,[0,0.2,0.25])
temparature['low'] = fuzz.trimf(temparature.universe,[0,0.25,0.5])
temparature['normal'] = fuzz.trimf(temparature.universe,[0.25,0.5,0.75])
temparature['high'] = fuzz.trimf(temparature.universe,[0.5,0.75,1])
temparature['very high'] = fuzz.trimf(temparature.universe,[0.75,0.85,1])

wind.view()
rainfall.view()
temparature.view()

# %%
rule1 = ctrl.Rule(temparature["very low"] & wind["very low"], rainfall["very low"])
rule2 = ctrl.Rule(temparature["low"] & wind["very low"], rainfall["very low"])
rule3 = ctrl.Rule(temparature["very low"] & wind["low"], rainfall["very low"])
rule4 = ctrl.Rule(temparature["low"] & wind["low"], rainfall["very low"])

rule5 = ctrl.Rule(temparature["normal"] & wind["very low"], rainfall["low"])
rule6 = ctrl.Rule(temparature["high"] & wind["very low"], rainfall["low"])
rule7 = ctrl.Rule(temparature["normal"] & wind["low"], rainfall["low"])
rule8 = ctrl.Rule(temparature["very low"] & wind["normal"], rainfall["low"])
rule9 = ctrl.Rule(temparature["low"] & wind["normal"], rainfall["low"])
rule10 = ctrl.Rule(temparature["very low"] & wind["high"], rainfall["low"])

rule11 = ctrl.Rule(temparature["very high"] & wind["very low"], rainfall["normal"])
rule12 = ctrl.Rule(temparature["high"] & wind["low"], rainfall["normal"])
rule13 = ctrl.Rule(temparature["normal"] & wind["normal"], rainfall["normal"])
rule14 = ctrl.Rule(temparature["low"] & wind["high"], rainfall["normal"])
rule15 = ctrl.Rule(temparature["very low"] & wind["very high"], rainfall["normal"])

rule16 = ctrl.Rule(temparature["very high"] & wind["low"], rainfall["high"])
rule17 = ctrl.Rule(temparature["high"] & wind["normal"], rainfall["high"])
rule18 = ctrl.Rule(temparature["very high"] & wind["normal"], rainfall["high"])
rule19 = ctrl.Rule(temparature["normal"] & wind["high"], rainfall["high"])
rule20 = ctrl.Rule(temparature["low"] & wind["very high"], rainfall["high"])
rule21 = ctrl.Rule(temparature["normal"] & wind["very high"], rainfall["high"])

rule22 = ctrl.Rule(temparature["high"] & wind["high"], rainfall["very high"])
rule23 = ctrl.Rule(temparature["very high"] & wind["high"], rainfall["very high"])
rule24 = ctrl.Rule(temparature["high"] & wind["very high"], rainfall["very high"])
rule25 = ctrl.Rule(temparature["very high"] & wind["very high"], rainfall["very high"])

RF_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25])
RFF= ctrl.ControlSystemSimulation(RF_ctrl)
RFF.input['wind']= 2
RFF.input['temparature']= 40
RFF.compute()
print(tipping.output['RF'])
tip.view(sim=RF)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-e1e657013c07> in <module>
#      29 rule25 = ctrl.Rule(temparature["very high"] & wind["very high"], rainfall["very high"])
#      30
# ---> 31 RF_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9, rule10, rule11, rule12, rule13, rule14, rule15, rule16, rule17, rule18, rule19, rule20, rule21, rule22, rule23, rule24, rule25])
#      32 RFF= ctrl.ControlSystemSimulation(RF_ctrl)
#      33 RFF.input['wind']= 2
#
# /usr/local/lib/python3.7/dist-packages/skfuzzy/control/controlsystem.py in __init__(self, rules)
#      45             if hasattr(rules, '__iter__'):
#      46                 for rule in rules:
# ---> 47                     self.addrule(rule)
#      48             else:
#      49                 try:
#
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl

"""Đầu vào"""
temp = ctrl.Antecedent(np.arange(20.4, 41.2, 0.01), "temperature")
wind = ctrl.Antecedent(np.arange(0.7, 3.1, 0.01), "windspeed")
"""Đầu ra"""
rainfall = ctrl.Consequent(np.arange(0.2, 9.1, 0.01), "rainfall")

temp["very low"] = fuzz.trimf(temp.universe, [20.4, 20.4, 25.6])
temp["low"] = fuzz.trimf(temp.universe, [20.4, 25.6, 30.8])
temp["normal"] = fuzz.trimf(temp.universe, [25.6, 30.8, 36])
temp["high"] = fuzz.trimf(temp.universe, [30.8, 36, 41.2])
temp["very high"] = fuzz.trimf(temp.universe, [36, 41.2, 41.2])

wind["very low"] = fuzz.trimf(wind.universe, [0.7, 0.7, 1.3])
wind["low"] = fuzz.trimf(wind.universe, [0.7, 1.3, 1.9])
wind["normal"] = fuzz.trimf(wind.universe, [1.3, 1.9, 2.5])
wind["high"] = fuzz.trimf(wind.universe, [1.9, 2.5, 3.1])
wind["very high"] = fuzz.trimf(wind.universe, [2.5, 3.1, 3.1])

rainfall["very low"] = fuzz.trimf(rainfall.universe, [0.2, 1.3125, 2.425])
rainfall["low"] = fuzz.trimf(rainfall.universe, [0.2, 2.425, 4.65])
rainfall["normal"] = fuzz.trimf(rainfall.universe, [2.425, 4.65, 6.875])
rainfall["high"] = fuzz.trimf(rainfall.universe, [4.65, 6.875, 9.1])
rainfall["very high"] = fuzz.trimf(rainfall.universe, [6.875, 7.9875, 9.1])

rule1 = ctrl.Rule(temp["very low"] & wind["very low"], rainfall["very low"])
rule2 = ctrl.Rule(temp["low"] & wind["very low"], rainfall["very low"])
rule3 = ctrl.Rule(temp["very low"] & wind["low"], rainfall["very low"])
rule4 = ctrl.Rule(temp["low"] & wind["low"], rainfall["very low"])

rule5 = ctrl.Rule(temp["normal"] & wind["very low"], rainfall["low"])
rule6 = ctrl.Rule(temp["high"] & wind["very low"], rainfall["low"])
rule7 = ctrl.Rule(temp["normal"] & wind["low"], rainfall["low"])
rule8 = ctrl.Rule(temp["very low"] & wind["normal"], rainfall["low"])
rule9 = ctrl.Rule(temp["low"] & wind["normal"], rainfall["low"])
rule10 = ctrl.Rule(temp["very low"] & wind["high"], rainfall["low"])

rule11 = ctrl.Rule(temp["very high"] & wind["very low"], rainfall["normal"])
rule12 = ctrl.Rule(temp["high"] & wind["low"], rainfall["normal"])
rule13 = ctrl.Rule(temp["normal"] & wind["normal"], rainfall["normal"])
rule14 = ctrl.Rule(temp["low"] & wind["high"], rainfall["normal"])
rule15 = ctrl.Rule(temp["very low"] & wind["very high"], rainfall["normal"])

rule16 = ctrl.Rule(temp["very high"] & wind["low"], rainfall["high"])
rule17 = ctrl.Rule(temp["high"] & wind["normal"], rainfall["high"])
rule18 = ctrl.Rule(temp["very high"] & wind["normal"], rainfall["high"])
rule19 = ctrl.Rule(temp["normal"] & wind["high"], rainfall["high"])
rule20 = ctrl.Rule(temp["low"] & wind["very high"], rainfall["high"])
rule21 = ctrl.Rule(temp["normal"] & wind["very high"], rainfall["high"])

rule22 = ctrl.Rule(temp["high"] & wind["high"], rainfall["very high"])
rule23 = ctrl.Rule(temp["very high"] & wind["high"], rainfall["very high"])
rule24 = ctrl.Rule(temp["high"] & wind["very high"], rainfall["very high"])
rule25 = ctrl.Rule(temp["very high"] & wind["very high"], rainfall["very high"])

RF_ctrl = ctrl.ControlSystem([rule1, rule2, rule3, rule4, rule5, rule6, rule7,
                                   rule8, rule9, rule10, rule11, rule12, rule13, rule14, 
                                   rule15, rule16, rule17, rule18, rule19, rule20, rule21, 
                                   rule22, rule23, rule24, rule25])
RF = ctrl.ControlSystemSimulation(RF_ctrl)
RF.input["temperature"] = 28
RF.input["windspeed"] = 2.8
RF.compute()
print(RF.output["rainfall"])
rainfall.view(sim = RF)
# Out:
# 5.762466345796148

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv('/content/Salary_Data.csv')
data.head()
data.shape
# Out:
# (30, 2)

# %%
x = data.drop(['Salary'], axis= True)
y = data['Salary']

# %%
from sklearn.model_selection import train_test_split 
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size = 0.2, random_state = 42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
sns.pairplot(data)

# %%
plt.plot(x_train, y_train,'r.', label = 'Train Data')
plt.xlable('Year Experience')
plt.ylable('Salary')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-425ae2318af1> in <module>
#       1 plt.plot(x_train, y_train,'r.', label = 'Train Data')
# ----> 2 plt.xlable('Year Experience')
#       3 plt.ylable('Salary')
#       4 plt.legend()
#       5 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test).round(1)
cal = pd.DataFrame(np.c_[y_test, y_pred], columns=['Original Salary','Predicted Salary'])
cal
print('Coefient',model.coef_)
print('Intercept',model.intercept_)
print('Accurary',model.score(X_train,y_train))
# Out:
# Coefient [9423.81532303]
# Intercept 25321.583011776813
# Accurary 0.9645401573418146

# %%
plt.scatter(X_train,y_train, color='red')
plt.plot(X_train,model.predict(X_train),color='blue')
plt.title('Salary vs Experience(Train set)')
plt.xlabel('Year of Experience')
plt.ylabel('Salary')
plt.show()
